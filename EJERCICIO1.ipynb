# %% [markdown]
# #***INICIANDO CON PYTHON***

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# **VARIABLES**

# %%
nombre = "Carlos Diaz"
print(nombre)
edad = 32
print(edad)
# Out:
# Carlos Diaz
# 32

# %%
edad = 22
print(edad)
edad = "Diana"
print(edad)
# Out:
# 22
# Diana

# %%
val = True
print(val)
# Out:
# True

# %%
nombre_P = "Carlos"
apellido = "Diaz"
print(nombre_P + " " + apellido)
# Out:
# Carlos Diaz

# %% [markdown]
# # # COMENTARIOS

# %% [markdown]
# 1. Documentación
# 2. Pruebas

# %%
# Variable para almacenar el teléfono
telefono = 3112215487
# Variable que almcena el nombre
nombre = "Karen Perez"
# Muestra por pantalla el telefono
# print(telefono)
# Muestra por pantalla el nombre
print(nombre)
# Out:
# Karen Perez

# %%
nombre_per = input("Digite su nombre: ")
print(nombre_per)
# Out:
# Digite su nombre: asd asdas das das dasd
# asd asdas das das dasd

# %% [markdown]
# **Taller**
#
# No de Identificación, Nombres, Apellidos, Dirección, Teléfono, Edad, Estado Civil, Número de hijos, Estatura en centímetros, fecha de contratación (Día/mes/año), Sueldo básico, Días Laborados.

# %%
cedula = input ("Digite numero de cedula:")
print(cedula)
nombre = input("Digite su nombre:")
apellido = input("Digite su apellido:")
print(nombre+apellido)
dire = input("Digite su direccion:")
print(dire)
telefono= input("Digite su numero de telefono:")
print(telefono)
edad = input("Digite su edad:")
print(edad)
estado_civil = input("digite su estado civil:")
print(estado_civil)
numero_hijo = input("digite su numero de hijos:")
print(numero_hijo)
estatura = input("Digitesu estatura(en centimetros):")
print(estatura)
fecha = input("digite su fecha de contratacion (dia/mes/año):")
print(fecha)
sueldo = input("digite su salario basico(sin puntos):")
print(sueldo)
dias = input("Digite los dias laborados en el mes:")
print(dias)
# Out:
# Digite numero de cedula:5254445
# 5254445
# Digite su nombre:carolina
# Digite su apellido:garcias
# carolinagarcias
# Digite su direccion:calld 847474hsddsd
# calld 847474hsddsd
# Digite su numero de telefono:31745554
# 31745554
# Digite su edad:55
# 55
# digite su estado civil:casada
# casada
# digite su numero de hijos:1
# 1
# Digitesu estatura(en centimetros):160
# 160
# digite su fecha de contratacion (dia/mes/año):13/09/2023
# 13/09/2023
# digite su salario basico(sin puntos):10287748565
# 10287748565
# Digite los dias laborados en el mes:41
# 41

# %%
cedula = input ("Digite numero de cedula:")
nombre = input("Digite su nombre:")
apellido = input("Digite su apellido:")
dire = input("Digite su direccion:")
telefono= input("Digite su numero de telefono:")
edad = input("Digite su edad:")
estado_civil = input("digite su estado civil:")
numero_hijo = input("digite su numero de hijos:")
estatura = input("Digitesu estatura(en centimetros):")
fecha = input("digite su fecha de contratacion (dia/mes/año):")
sueldo = input("digite su salario basico(sin puntos):")
dias = input("Digite los dias laborados en el mes:")
mensaje = ("los datos digitados son:")
print(mensaje)
print(cedula)
print(nombre+apellido)
print(dire)
print(telefono)
print(edad)
print(estado_civil)
print(numero_hijo)
print(estatura)
print(fecha)
print(sueldo)
print(dias)
# Out:
# Digite numero de cedula:55454
# Digite su nombre:fjjfhf
# Digite su apellido:fjfhfhgf
# Digite su direccion:dydysvs
# Digite su numero de telefono:5475421
# Digite su edad:45
# digite su estado civil:dasdis
# digite su numero de hijos:5
# Digitesu estatura(en centimetros):45421
# digite su fecha de contratacion (dia/mes/año):5/7/6464
# digite su salario basico(sin puntos):4124846
# Digite los dias laborados en el mes:45
# los datos digitados son:
# 55454
# fjjfhffjfhfhgf
# dydysvs
# 5475421
# 45
# dasdis
# 5
# 45421
# 5/7/6464
# 4124846
# 45
